# %% [markdown]
# <a href="https://colab.research.google.com/github/sweetscoding/belajarMLfrom-Zero/blob/main/02_Data_Cleaning_Visualization_Starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Install Library

# %%
# !pip install pandas seaborn matplotlib scikit-learn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## 2. Import Library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Persiapan

# %% [markdown]
# ### a. Membaca File Harga Rumah (CSV)

# %% [markdown]
# Mendownload file CSV yang berisi data harga rumah hasil web scraping dari website.

# %%
! gdown 1vY3aw4DrDBRVboI7tqn4WTI9ZSnerzdR

# %% [markdown]
# Membaca File CSV

# %%
# !pwd
# Out:
# /content

# %%
data = pd.read_csv('harga_rumah.csv')

# %% [markdown]
# ### b. Menampilkan Beberapa Data

# %% [markdown]
# Menampilkan Beberapa Data Pertama (`head()`)

# %%
data.head(7)
# Out:
#               city                                              title  \
# 0  Jakarta Selatan  Dijual Rumah Sultan Mewah Full Furnish Di Kema...
# 1  Jakarta Selatan       Rumah Mewah S Pool Cilandak  Jakarta Selatan
# 2  Jakarta Selatan  Rumah Mewah 3 Lantai Ada Roof Top, Dalam Kompl...
# 3  Jakarta Selatan  Rumah 1 Lantai Di Cipete Kebayoran Baru Lokasi...
# 4  Jakarta Selatan  Rumah Bagus Rapih Siap Huni di Sektor 6 Bintar...
# 5  Jakarta Selatan  Dijual Rumah Cluster Private Pool Di Kebagusan...
# 6  Jakarta Selatan  Dijual Rumah Cluster Di Jagakarsa Jakarta Selatan
#
#             price                       location       area building_area  \
# 0    Rp 45 Miliar        Kemang, Jakarta Selatan   : 730 m²     : 1100 m²
# 1  Rp 69,9 Miliar      Cilandak, Jakarta Selatan  : 4500 m²     : 2500 m²
# 2  Rp 7,91 Miliar  Pondok Indah, Jakarta Selatan   : 128 m²      : 302 m²
# 3  Rp 14,5 Miliar        Cipete, Jakarta Selatan   : 518 m²      : 450 m²
# 4     Rp 3 Miliar       Bintaro, Jakarta Selatan   : 120 m²       : 90 m²
# 5  Rp 4,25 Miliar     Kebagusan, Jakarta Selatan   : 127 m²      : 280 m²
# 6     Rp 875 Juta     Jagakarsa, Jakarta Selatan    : 38 m²       : 80 m²
#
#    bedrooms  bathrooms  garage
# 0       7.0        8.0    10.0
# 1      12.0        8.0     5.0
# 2       3.0        3.0     2.0
# 3       5.0        6.0     5.0
# 4       4.0        2.0     NaN
# 5       6.0        5.0     1.0
# 6       3.0        3.0     1.0

# %% [markdown]
# Menampilkan Beberapa Data Terakhir (`tail()`)

# %%
data.tail(10)
# Out:
#         city                                              title  \
# 1987  Bekasi  Rumah Seken Terawat dekat Lagoon Avenue Mall B...
# 1988  Bekasi  Rumah 2Lt Hadap Selatan dekat Metropolitan Mal...
# 1989  Bekasi  Rumah SHM LT 128 Harga Nego 15 Mnt ke Grand Ga...
# 1990  Bekasi  Rumah Bebas Banjir LT 250 Harga Nego 10 Menit ...
# 1991  Bekasi  Rumah Cantik Aesthetic Di Mutiara Gading City,...
# 1992  Bekasi  Rumah Vernonia Residence 9x18 Standard Summare...
# 1993  Bekasi       Dijual Rumah bagus di Citra gran cibubur CBD
# 1994  Bekasi  Rumah Di Wibawa Mukti, Jatiasih, Jatisari, Bek...
# 13    Rp 45 Miliar         Senayan, Jakarta Selatan   : 712 m²      : 500 m²
# 14  Rp 12,5 Miliar     Lebak Bulus, Jakarta Selatan   : 446 m²      : 500 m²
# 15   Rp 7,3 Miliar   Permata Hijau, Jakarta Selatan   : 356 m²      : 450 m²
#
#     bedrooms  bathrooms  garage
# 6        3.0        3.0     1.0
# 7        3.0        3.0     2.0
# 8        5.0        3.0     NaN
# 9        4.0        4.0     1.0
# 10       5.0        4.0     2.0
# 11       4.0        3.0     1.0
# 12       2.0        2.0     1.0
# 13       6.0        5.0     3.0
# 14       4.0        3.0     NaN
# 15       5.0        4.0     1.0

# %% [markdown]
# ### c. Menampilkan Statistik Deskriptif

# %% [markdown]
# Statistik deskriptif adalah informasi global tentang data. Berisi statistik seperti mean, median, std, min, max, dan lain-lain.
#
# >
# > Hanya untuk kolom numerik
# >

# %%
data.describe()
# Out:
#           bedrooms    bathrooms       garage
# count  1979.000000  1973.000000  1282.000000
# mean      3.565942     2.891536     1.893916
# std       2.100862     2.050675     1.335743
# min       1.000000     1.000000     1.000000
# 25%       3.000000     2.000000     1.000000
# 50%       3.000000     3.000000     2.000000
# 75%       4.000000     4.000000     2.000000
# max      50.000000    50.000000    15.000000

# %% [markdown]
# ## 4. Penangangan Missing Value

# %% [markdown]
# Missing value adalah nilai yang kosong atau tidak ada. Missing value dapat mempengaruhi analisis data dan hasil prediksi model machine learning. Oleh karena itu, perlu dilakukan penanganan secara baik.

# %% [markdown]
# ### a. Mengecek Missing Value

# %%
data.isnull().sum()
# Out:
# city               0
# title              0
# price              0
# location           0
# area               0
# building_area     21
# bedrooms          18
# bathrooms         24
# garage           715
# dtype: int64

# %% [markdown]
# Dari hasil di atas, terlihat bahwa ada beberapa missing value di kolom `building_area`, `bedrooms`, `bathrooms` dan `garage`.

# %% [markdown]
# Untuk mengecek data apa saja yang memiliki `building_area` null, kita bisa menggunakan perintah berikut:

# %%
data[data['building_area'].isnull()]
# Out:
#                  city                                              title  \
# 26    Jakarta Selatan                Dijual Cepat Rmh Kost Putri Terbaik
# 45    Jakarta Selatan  Rumah Akses Jalan 2 Mobil - Hanya Hitung Harga...
# 97    Jakarta Selatan    Jual Rumah Hitung Tanah Prime Area Pondok Indah
# 132   Jakarta Selatan    Jual Rumah Hitung Tanah Prime Area Pondok Indah
# 305     Jakarta Timur          Rumah Siap Huni Kavling Dki Pondok Kelapa
# 690     Jakarta Pusat  Rumah Salemba Raya 1 820 M2 32X25 Bisa Dibangu...
# 702     Jakarta Pusat  Rumah Tua Hitung Tanah Komersial Di Teuku Cik ...
# 703     Jakarta Pusat  Cepat Rumah Pinggir Jalan 2,5 Lt Di Kramat Sen...
# 712     Jakarta Pusat  Dijual Menteng Komersial Area Jalan Lebar Jara...
# 731     Jakarta Pusat        Rumah Lama Di Taman Amir Hamzah, Proklamasi
# 748     Jakarta Pusat  Rumah Di Menteng, Colonial Style Cocok Untuk R...
# 864     Jakarta Utara  Jual Termurah Rumah Arcadia 4,5X10 3 Lantai Pi...
# 940     Jakarta Utara  Dijual Cepat! Rumah Ukuran 200 M2 Dan 3 Lantai...
# 1864           NaN       NaN        NaN     NaN

# %% [markdown]
# ### b. Penanganan Missing Value pada Kolom `building_area`, `bedrooms` dan `bathrooms`

# %% [markdown]
# Agar DataFrame original tetap ada, kita perlu melakukan copy terlebih dahulu DataFrame tersebut. Kemudian penanganan missing value akan dilakukan pada DataFrame copy tersebut. Tujuannya adalah agar kita tetap dapat mengakses DataFrame original jika diperlukan. Ini adalah best practice dalam data pre-processing.

# %%
data_no_missing = data.copy()

# %% [markdown]
# > Sebuah rumah yang ingin dijual sebenernya aneh jika tidak ada data `building_area`, `bedrooms` dan `bathrooms`. Kemungkinan hal ini terjadi karena kesalahan input data. Dan karena jumlah data missing pada 3 kolom tidak terlalu banyak, maka langkah yang paling sederhana adalah dengan menghapus data tersebut.

# %%
len(data_no_missing[data_no_missing['building_area'].isnull()])
# Out:
# 21

# %%
data_no_missing = data_no_missing.dropna(subset=['building_area', 'bedrooms', 'bathrooms'])

# %% [markdown]
# Sekarang cek kembali missing value.

# %%
data_no_missing.isnull().sum()
# Out:
# city               0
# title              0
# price              0
# location           0
# area               0
# building_area      0
# bedrooms           0
# bathrooms          0
# garage           689
# dtype: int64

# %% [markdown]
# Terlihat bahwa, missing value terdapat pada kolom `building_area`, `bedrooms` dan `bathrooms` sudah tidak ada. Yang masih terdapat missing value adalah kolom `garage`.

# %% [markdown]
# ### c. Penanganan Missing Value pada Kolom `garage`

# %% [markdown]
# Jika sebuah rumah tidak ada data `garaga`, maka berarti memang rumah tersebut tidak memiliki garage. Jadi sebenernya tidak ada masalah dengan data tersebut. Hanya saja terdeteksi sebagai `NaN`. Untuk memperbaikinya, kita bisa mengisi data tersebut dengan 0.

# %%
data_no_missing['garage'] = data_no_missing['garage'].fillna(0)

# %% [markdown]
# Kemudian, kita coba cek sekali lagi, apakah masih ada data missing?

# %%
data_no_missing.isnull().sum()
# Out:
# city             0
# title            0
# price            0
# location         0
# area             0
# building_area    0
# bedrooms         0
# bathrooms        0
# garage           0
# dtype: int64

# %% [markdown]
# Data missing sudah tidak ada.

# %% [markdown]
# ## 5. Perbaikan Data Duplicate

# %% [markdown]
# Data duplicate adalah data yang memiliki nilai yang sama di seluruh kolomnya. Kita perlu menghapus data duplicate tersebut karena data duplicate akan mempengaruhi analisis dan prediksi model.

# %% [markdown]
# ### a. Mengecek Data Duplikat

# %% [markdown]
# Untuk mengecek data duplikat, kita bisa menggunakan metode `duplicated()`. Metode ini akan mengembalikan boolean series yang menandai baris-baris yang duplikat.

# %%
duplicate = data_no_missing.duplicated()

# %% [markdown]
# Selanjutnya, kita bisa menggunakan series tersebut sebagai masking untuk menampilkan semua data yang duplicate.
#
# > `sort_values()` untuk sorting data berdasarkan `city`

# %%
data_no_missing[duplicate].sort_values('city')
# Out:
#                    city                                              title  \
# 1966             Bekasi  Rumah 3 Lt SHM Bebas Banjir 15 menit ke Rumah ...
# 1965             Bekasi  Rumah Murah Bebas Banjir dekat Kota Cinema Mal...
# 1039              Bogor       Rumah Minimalis Modern Siap Huni Kota Wisata
# 1040              Bogor  Rumah Modern 2 Lantai Siap Huni Lokasi Strateg...
# 1042              Bogor  Dijual Rumah Siap Huni Sisa Tanah Belakang Mas...
# ...                 ...                                                ...
# 1646  Tangerang Selatan  Rumah 2 Lantai 15 Menit ke Mall Paradise Walk ...
# 1633  Tangerang Selatan  Rumah Strategis LT 120 Dekat Sekolah dan RS di...
# 1627  Tangerang Selatan  Rumah Baru Renov di Pamulang 10 Menit ke RSIA ...
# 1652  Tangerang Selatan         Dijual Rumah Di Bintaro Sektor 3 Brand New
# 1631  Tangerang Selatan  Rumah Baru Siap Huni di Pamulang Dekat RSIA Bu...
#
#                price                     location      area building_area  \
# 1966     Rp 1 Miliar            Jati Asih, Bekasi   : 89 m²      : 160 m²
# 1965     Rp 560 Juta            Jati Asih, Bekasi   : 72 m²       : 72 m²
# 1039  Rp 1,15 Miliar           Kota Wisata, Bogor   : 90 m²       : 75 m²
# 1040  Rp 1,65 Miliar           Kota Wisata, Bogor   : 84 m²       : 92 m²
# 1042  Rp 3,95 Miliar           Sentul City, Bogor  : 287 m²      : 250 m²
# ...              ...                          ...       ...           ...
# 1646     Rp 910 Juta   Serpong, Tangerang Selatan   : 81 m²       : 51 m²
# 1633  Rp 1,57 Miliar  Pamulang, Tangerang Selatan  : 120 m²       : 65 m²
# 1627  Rp 1,57 Miliar  Pamulang, Tangerang Selatan  : 120 m²       : 65 m²
# 1652   Rp 7,9 Miliar   Bintaro, Tangerang Selatan  : 250 m²      : 420 m²
# 1631   Rp 1,2 Miliar  Pamulang, Tangerang Selatan   : 98 m²       : 66 m²
#
#       bedrooms  bathrooms  garage
# 1966       4.0        2.0     0.0
# 1965       3.0        2.0     0.0
# 1039       2.0        2.0     1.0
# 1040       3.0        2.0     2.0
# 1042       3.0        4.0     2.0
# ...        ...        ...     ...
# 1646       3.0        2.0     0.0
# 1633       2.0        2.0     0.0
# 1627       2.0        2.0     0.0
# 1652       4.0        4.0     2.0
# 1631       3.0        2.0     0.0
#
# [129 rows x 9 columns]

# %% [markdown]
# Data di atas adalah data-data yang muncul lebih dari 1 kali (duplikat). Untuk mengecek lebih detail, kita akan coba cek 1 data, yaitu rumah dengan city `Bekasi` dan price `Rp 560 Juta` dan bedrooms `3`.

# %%
data_no_missing[(data_no_missing.city == "Bekasi") & (data_no_missing.price == "Rp 560 Juta") & (data_no_missing.bedrooms == 3)]
# Out:
#         city                                              title        price  \
# 1962  Bekasi  Rumah Murah Bebas Banjir dekat Kota Cinema Mal...  Rp 560 Juta
# 1965  Bekasi  Rumah Murah Bebas Banjir dekat Kota Cinema Mal...  Rp 560 Juta
#
#                location     area building_area  bedrooms  bathrooms  garage
# 1962  Jati Asih, Bekasi  : 72 m²       : 72 m²       3.0        2.0     0.0
# 1965  Jati Asih, Bekasi  : 72 m²       : 72 m²       3.0        2.0     0.0

# %% [markdown]
# Terlihat bahwa data tersebut duplikat.

# %% [markdown]
# ### b. Menangani Data Duplikat

# %% [markdown]
# Untuk menangani data duplikat, kita bisa menggunakan metode `drop_duplicates()`. Metode ini akan menghapus semua baris yang duplikat. Dengan metode ini, data yang duplikas hanya akan tersisa satu pada DataFrame.

# %%
data_no_duplicate = data_no_missing.drop_duplicates()

# %% [markdown]
# Sekarang sudah tidak ada lagi data duplikat. Untuk memastikan, kita bisa mengecek sekali lagi menggunakan perintah `duplicated()`

# %%
len(data_no_duplicate)
# Out:
# 1841

# %%
cek_duplicate = data_no_duplicate.duplicated()
data_no_duplicate[cek_duplicate]
# Out:
# Empty DataFrame
# Columns: [city, title, price, location, area, building_area, bedrooms, bathrooms, garage]
# Index: []

# %%
print("jumlah data duplikat", len(data_no_duplicate[duplicate]))
# Out:
# jumlah data duplikat 0
# /tmp/ipython-input-31014023.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print("jumlah data duplikat", len(data_no_duplicate[duplicate]))

# %% [markdown]
# Terlihat bahwa sudah tidak ada data duplikat.

# %% [markdown]
# ## 6. Menangani Data yang Tidak Konsisten (Handling Inconsistent Data)

# %% [markdown]
# Data yang tidak konsisten adalah data yang tidak sesuai dengan format atau tipe data yang seharusnya. Misal, format data yang seharusnya angka tetapi ada data yang berupa huruf. Pada data harga rumah, kolom `price`, `area` dan  `building_area` memiliki format yang tidak sesuai. Kolom-kolom ini seharusnya berupa angka agar dapat diproses oleh model machine learning. Kita akan coba perbaiki.

# %% [markdown]
# ### a. Menangani Data `price`

# %% [markdown]
# Sebelum menangani data `price`, kita akan coba melihat dulu gambaran umum dari data `price`. Sekilas terlihat format data price adalah `Rp X Miliar` atau `Rp X Juta`. Kita definisikan fungsi `check_unique` untuk melihat apakah ada format lain.

# %%
def check_unique_value(df, column):
    unique_values = df[column].unique()
    print(f"Unique values in column: {column}: {unique_values}")
    print(f"Number of unique values: {len(unique_values)}")

# %% [markdown]
# Selanjutnya kita coba cek data `price` dengan fungsi tersebut.

# %%
cek_data_unik = check_unique_value(data_no_duplicate, "price")
print(cek_data_unik)
# Out:
# Unique values in column: price: ['Rp 45 Miliar' 'Rp 69,9 Miliar' 'Rp 7,91 Miliar' 'Rp 14,5 Miliar'
#  'Rp 3 Miliar' 'Rp 4,25 Miliar' 'Rp 875 Juta' 'Rp 16,9 Miliar'
#  'Rp 21,5 Miliar' 'Rp 25 Miliar' 'Rp 14 Miliar' 'Rp 2,5 Miliar'
#  'Rp 2,65 Miliar' 'Rp 12,5 Miliar' 'Rp 7,3 Miliar' 'Rp 1,42 Miliar'
#  'Rp 68 Miliar' 'Rp 770 Juta' 'Rp 1,74 Miliar' 'Rp 8,45 Miliar'
#  'Rp 6,87 Miliar' 'Rp 4,8 Miliar' 'Rp 7 Miliar' 'Rp 3,5 Miliar'
#  'Rp 35 Miliar' 'Rp 10,6 Miliar' 'Rp 55 Miliar' 'Rp 13,4 Miliar'
#  'Rp 18,9 Miliar' 'Rp 50 Miliar' 'Rp 7,5 Miliar' 'Rp 6 Miliar'
#  'Rp 2,75 Miliar' 'Rp 4,2 Miliar' 'Rp 1,45 Miliar' 'Rp 31 Miliar'
#  'Rp 12 Miliar' 'Rp 17,5 Miliar' 'Rp 998 Juta' 'Rp 24 Miliar'
#  'Rp 3,45 Miliar' 'Rp 37 Miliar' 'Rp 39,9 Miliar' 'Rp 8,5 Miliar'
#  'Rp 19,7 Miliar' 'Rp 9,5 Miliar' 'Rp 1,75 Miliar' 'Rp 39 Miliar'
#  'Rp 2,67 Miliar' 'Rp 2,16 Miliar' 'Rp 4,15 Miliar' 'Rp 4,31 Miliar'
#  'Rp 6,63 Miliar' 'Rp 350 Juta' 'Rp 635 Juta' 'Rp 775 Juta' 'Rp 360 Juta'
#  'Rp 725 Juta' 'Rp 430 Juta' 'Rp 694 Juta' 'Rp 783 Juta' 'Rp 795 Juta'
#  'Rp 929 Juta' 'Rp 3,48 Miliar' 'Rp 4,68 Miliar' 'Rp 699 Juta'
#  'Rp 3,76 Miliar' 'Rp 4,29 Miliar' 'Rp 1,68 Miliar' 'Rp 640 Juta'
#  'Rp 575 Juta' 'Rp 799 Juta']
# Number of unique values: 504
# None

# %% [markdown]
# Terlihat bahwa, ada format lain yaitu `Rp 13,9 MiliarRp 14.5MHEMAT 550 Jutaan`.

# %% [markdown]
# #### Mendefinisikan Fungsi `convert_to_million`

# %% [markdown]
# Fungsi ini untuk mengkonvert text `price` menjadi angka dengan mengacu pada 3 format di atas, yaitu:
#
# 1. `Rp X Miliar`
# 2. `Rp X Juta`
# 3. `Rp X MiliarRp YYMHEMAT ZZ Jutaan`
#
# > Fungsi ini sekaligus membuat kolom `price` menjadi dalam jutaan

# %%
# Definisikan sebuah fungsi untuk konvert ke format standard
import re #reguler expression

def convert_to_million(price):
    # Hapus semua spasi dan karakter tambahan
    price = re.sub(r'\s+', '', price)

    # ambil hanya bagian harga utama (sebelum bagian tambahan HEMAT dll)
    main_price = re.search(r'Rp\d+[,.]?\d*(Miliar|Juta)', price)

    # jika main price null
    if not main_price:
        return 0

    # extract main price
    main_price = main_price.group()
    # Hapus 'Rp' dan spasi
    main_price = main_price.replace('Rp', '').strip()
    # Ganti koma dengan titik untuk desimal
    main_price = main_price.replace(',', '.')

    try:
        # jika "Miliar", kalikan 1000
        if 'Miliar' in main_price:
            value = float(main_price.replace('Miliar', '').strip()) * 1000
        elif 'Juta' in main_price:
            value = float(main_price.replace('Juta', '').strip())
        else:
            value = 0
    except ValueError:
        value = 0

    return value

# %% [markdown]
# Setelah itu, seperti biasa, kita perlu melakukan copy DataFrame terlebih dahulu.

# %%
data_transformed = data_no_duplicate.copy()

# %% [markdown]
# Setelah itu, kita lakukan convert

# %%
data_transformed['price'] = data_transformed['price'].apply(lambda x: convert_to_million(x))

# %% [markdown]
# Oke, sekarang cek hasil konversi. Kita tampilkan beberapa data pertama

# %%
data_transformed.head()
# Out:
#               city                                              title  \
# 0  Jakarta Selatan  Dijual Rumah Sultan Mewah Full Furnish Di Kema...
# 1  Jakarta Selatan       Rumah Mewah S Pool Cilandak  Jakarta Selatan
# 2  Jakarta Selatan  Rumah Mewah 3 Lantai Ada Roof Top, Dalam Kompl...
# 3  Jakarta Selatan  Rumah 1 Lantai Di Cipete Kebayoran Baru Lokasi...
# 4  Jakarta Selatan  Rumah Bagus Rapih Siap Huni di Sektor 6 Bintar...
#
#      price                       location       area building_area  bedrooms  \
# 0  45000.0        Kemang, Jakarta Selatan   : 730 m²     : 1100 m²       7.0
# 1  69900.0      Cilandak, Jakarta Selatan  : 4500 m²     : 2500 m²      12.0
# 2   7910.0  Pondok Indah, Jakarta Selatan   : 128 m²      : 302 m²       3.0
# 3  14500.0        Cipete, Jakarta Selatan   : 518 m²      : 450 m²       5.0
# 4   3000.0       Bintaro, Jakarta Selatan   : 120 m²       : 90 m²       4.0
#
#    bathrooms  garage
# 0        8.0    10.0
# 1        8.0     5.0
# 2        3.0     2.0
# 3        6.0     5.0
# 4        2.0     0.0

# %% [markdown]
# Terlihat bahwa data `price` sudah berubah menjadi numeric

# %% [markdown]
# Terakhir, kita coba gunakan fungsi `describe` untuk memastikan bahwa data `price` sudah memiliki tipe data numeric

# %%
data_transformed.describe()
# Out:
#                price     bedrooms    bathrooms       garage
# count    1841.000000  1841.000000  1841.000000  1841.000000
# mean     6664.863118     3.565997     2.889191     1.225964
# std     15928.013409     2.146817     2.096503     1.401474
# min       130.000000     1.000000     1.000000     0.000000
# 25%      1100.000000     3.000000     2.000000     0.000000
# 50%      2400.000000     3.000000     3.000000     1.000000
# 75%      5150.000000     4.000000     4.000000     2.000000
# max    294000.000000    50.000000    50.000000    15.000000

# %% [markdown]
# ### b. Menangani Data `area` dan `building_area`

# %% [markdown]
# Langkah selanjutnya adalah memperbaiki format data pada kolom `area` dan `building_area`. Kita perlu menghapus tanda titik dua (:) dan juga tanda m². Setelah itu, mengubah tipe data menjadi numerik.

# %% [markdown]
# Langkah pertama adalah mengecek pola umum dari data `area`. Kita bisa menggunakan fungsi `check_unique_value` yang sudah kita buat sebelumnya.

# %%
print(check_unique_value(data_transformed, "area"))
# Out:
# Unique values in column: area: [': 730 m²' ': 4500 m²' ': 128 m²' ': 518 m²' ': 120 m²' ': 127 m²'
#  ': 38 m²' ': 208 m²' ': 1322 m²' ': 662 m²' ': 442 m²' ': 93 m²'
#  ': 100 m²' ': 712 m²' ': 446 m²' ': 356 m²' ': 60 m²' ': 2950 m²'
#  ': 30 m²' ': 105 m²' ': 250 m²' ': 433 m²' ': 187 m²' ': 150 m²'
#  ': 325 m²' ': 236 m²' ': 317 m²' ': 1390 m²' ': 408 m²' ': 449 m²'
#  ': 600 m²' ': 623 m²' ': 252 m²' ': 470 m²' ': 714 m²' ': 2363 m²'
#  ': 345 m²' ': 290 m²' ': 109 m²' ': 180 m²' ': 525 m²' ': 160 m²'
#  ': 300 m²' ': 32 m²' ': 454 m²' ': 426 m²' ': 140 m²' ': 342 m²'
#  ': 441 m²' ': 1152 m²' ': 332 m²' ': 710 m²' ': 555 m²' ': 80 m²'
#  ': 528 m²' ': 2835 m²' ': 700 m²' ': 1192 m²' ': 633 m²' ': 680 m²'
#  ': 348 m²' ': 531 m²' ': 108 m²' ': 819 m²' ': 262 m²' ': 760 m²'
#  ': 81 m²' ': 353 m²' ': 370 m²' ': 274 m²' ': 129 m²' ': 186 m²'
#  ': 111 m²' ': 133 m²' ': 71 m²' ': 235 m²' ': 74 m²' ': 1190 m²'
#  ': 580 m²' ': 244 m²' ': 318 m²' ': 400 m²' ': 264 m²' ': 72 m²'
#  ': 530 m²' ': 247 m²' ': 141 m²' ': 89 m²' ': 587 m²' ': 110 m²'
#  ': 1096 m²' ': 284 m²' ': 3350 m²' ': 529 m²' ': 548 m²' ': 920 m²'
#  ': 102 m²' ': 372 m²' ': 3000 m²' ': 97 m²' ': 787 m²' ': 43 m²'
#  ': 244 m²' ': 403 m²' ': 271 m²' ': 617 m²' ': 1724 m²' ': 134 m²'
#  ': 404 m²' ': 374 m²' ': 522 m²' ': 109 m²' ': 277 m²' ': 192 m²'
#  ': 1200 m²' ': 362 m²' ': 262 m²' ': 269 m²' ': 1500 m²' ': 620 m²'
#  ': 255 m²' ': 371 m²' ': 237 m²' ': 616 m²' ': 739 m²' ': 563 m²'
#  ': 837 m²' ': 66 m²' ': 720 m²' ': 224 m²' ': 142 m²' ': 209 m²'
#  ': 96 m²' ': 1 m²' ': 540 m²' ': 810 m²' ': 2800 m²' ': 489 m²'
#  ': 216 m²' ': 1125 m²' ': 123 m²' ': 1311 m²' ': 176 m²' ': 206 m²'
#  ': 221 m²' ': 320 m²' ': 61 m²' ': 106 m²' ': 47 m²' ': 388 m²'
#  ': 173 m²' ': 143 m²' ': 444 m²' ': 358 m²' ': 119 m²' ': 99 m²'
#  ': 67 m²' ': 29 m²' ': 33 m²' ': 30 m²' ': 196 m²' ': 136 m²' ': 420 m²'
#  ': 148 m²' ': 375 m²' ': 54 m²' ': 346 m²' ': 635 m²' ': 68 m²' ': 28 m²'
#  ': 62 m²' ': 159 m²' ': 131 m²' ': 65 m²' ': 243 m²' ': 157 m²'
#  ': 127 m²' ': 2783 m²' ': 57 m²' ': 278 m²' ': 328 m²' ': 64 m²'
#  ': 202 m²' ': 101 m²' ': 56 m²' ': 93 m²' ': 52 m²' ': 155 m²' ': 147 m²'
#  ': 195 m²' ': 114 m²' ': 126 m²' ': 163 m²' ': 175 m²' ': 838 m²'
#  ': 77 m²' ': 198 m²' ': 401 m²' ': 241 m²' ': 1831 m²' ': 425 m²'
#  ': 416 m²' ': 86 m²' ': 83 m²' ': 132 m²' ': 113 m²' ': 356 m²'
#  ': 245 m²' ': 306 m²' ': 182 m²' ': 133 m²' ': 695 m²' ': 545 m²'
#  ': 465 m²' ': 49 m²' ': 343 m²' ': 595 m²' ': 248 m²' ': 1139 m²'
#  ': 445 m²' ': 166 m²' ': 117 m²' ': 304 m²' ': 51 m²' ': 298 m²'
#  ': 191 m²' ': 285 m²' ': 179 m²' ': 385 m²' ': 249 m²' ': 139 m²'
#  ': 183 m²' ': 107 m²' ': 194 m²' ': 305 m²' ': 124 m²' ': 265 m²'
#  ': 219 m²' ': 149 m²']
# Number of unique values: 334
# None

# %% [markdown]
# Data `building_area` juga hanya ada 1 format yaitu `: XX m²`.

# %% [markdown]
# #### Membuat Fungsi `clean_area`

# %% [markdown]
# Untuk memudahkan, sekarang kita akan membuat fungsi bernama `clean_area` dan `transform_area` untuk membersihkan dan mengubah data area menjadi numerik.

# %%
import re

def clean_area(area):
    # bersihkan tanda : dan m²
    return float(re.sub(r'[:m²]', '', area).strip())

def transform_area(df, column):
    df[column] = df[column].apply(lambda x: clean_area(x))

# %% [markdown]
# Setelah itu, kita panggil fungsi di atas

# %%
transform_area(data_transformed, "area")

# %%
transform_area(data_transformed, "building_area")

# %% [markdown]
# Langkah terakhir, cek apakah format data untuk `area` dan `building_area` sudah sesuai.

# %%
data_transformed.tail()
# Out:
#         city                                              title   price  \
# 1992  Bekasi  Rumah Vernonia Residence 9x18 Standard Summare...  3200.0
# 1993  Bekasi       Dijual Rumah bagus di Citra gran cibubur CBD  2850.0
# 1994  Bekasi  Rumah Di Wibawa Mukti, Jatiasih, Jatisari, Bek...   799.0
# 1995  Bekasi  Rumah Baru Bagus Murah Kali Di Taman Harapan Baru   570.0
# 1996  Bekasi   Dijual Rumah Di Grand Mutiara Gading Setu Bekasi   450.0
#
#                        location   area  building_area  bedrooms  bathrooms  \
# 1992  Summarecon Bekasi, Bekasi  162.0          149.0       3.0        3.0
# 1993            Cibubur, Bekasi  120.0          112.0       3.0        2.0
# 1994             Bekasi, Bekasi  150.0          120.0       3.0        2.0
# 1995      Harapan Indah, Bekasi   66.0           50.0       2.0        1.0
# 1996               Setu, Bekasi   60.0           40.0       2.0        1.0
#
#       garage
# 1992     2.0
# 1993     0.0
# 1994     1.0
# 1995     1.0
# 1996     1.0

# %% [markdown]
# Terlihat sudah sesuai. Terakhir kita cek juga menggunakan fungsi `describe()` untuk memastikan formatnya sudah numerik.

# %%
data_transformed.describe()
# Out:
#                price          area  building_area     bedrooms    bathrooms  \
# count    1841.000000   1841.000000    1841.000000  1841.000000  1841.000000
# mean     6664.863118    224.128191     238.581206     3.565997     2.889191
# std     15928.013409    554.887435     633.033996     2.146817     2.096503
# min       130.000000     16.000000       1.000000     1.000000     1.000000
# 25%      1100.000000     81.000000      80.000000     3.000000     2.000000
# 50%      2400.000000    120.000000     150.000000     3.000000     3.000000
# 75%      5150.000000    223.000000     265.000000     4.000000     4.000000
# max    294000.000000  20400.000000   25000.000000    50.000000    50.000000
#
#             garage
# count  1841.000000
# mean      1.225964
# std       1.401474
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max      15.000000

# %% [markdown]
# ## 7. Check Distribusi Data `price`

# %%
sns.displot(data_transformed['price'], kde=True)

# %% [markdown]
# Terlihat bahwa data `price` tidak berdistribusi normal.

# %% [markdown]
# ## 8. Plot Hubungan Variabel `price` dengan Variabel lainnya

# %% [markdown]
# Tujuan pengecekan adalah untuk mengetahui hubungan antara variabel `price` dan variabel lainnya. Jika hubungan tidak signifikan atau tidak memiliki hubungan, maka variabel tersebut tidak perlu dijadikan fitur.

# %% [markdown]
# ### a. Hubungan Variabel `price` dan `area`

# %%
data = pd.concat([data_transformed['price'], data_transformed['area']], axis=1)
data.plot.scatter(x='area',
                  y='price')
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %% [markdown]
# Terlihat bahwa ada korelasi positive antara `price` dan `area`. Artinya ketika area rumah semakin besar, maka harga rumah cenderung semakin mahal. Walaupun terlihat 1 data outlier di sebelah kanan dan kiri atas. Data outlier ini mungkin perlu dihapus agar tidak mempengaruhi model yang akan dibuat.

# %% [markdown]
# Coba cari rumah dengan `area` di atas `20000 m2`

# %%
data_transformed[data_transformed['area'] > 20000]
# Out:
#                 city                                              title  \
# 164  Jakarta Selatan  Pasar Minggu, Rumah Siap Huni Di Dalam Komplek...
#
#       price                       location     area  building_area  bedrooms  \
# 164  5500.0  Pasar Minggu, Jakarta Selatan  20400.0        25000.0       4.0
#
#      bathrooms  garage
# 164        2.0     2.0

# %% [markdown]
# #### Membuang Data yang Outlier

# %% [markdown]
# Sekarang kita akan membuang 1 data outlier di atas

# %%
data_no_outlier = data_transformed.copy()

# %%
data_no_outlier = data_no_outlier[data_no_outlier['area'] < 20000]

# %%
len(data_no_outlier)
# Out:
# 1840

# %% [markdown]
# ### b. Hubungan Variabel `price` dan `building_area`

# %%
data = pd.concat([data_no_outlier['price'], data_no_outlier['building_area']], axis=1)
data.plot.scatter(x='building_area',
                  y='price')
# Out:
# <Axes: xlabel='building_area', ylabel='price'>

# %% [markdown]
# Sekilas terdapat 4 data yang nampak outlier. Coba cari data `building_area` di atas 1800 dan `price` di bawah 40M

# %%
data_no_outlier[(data_no_outlier['building_area'] > 1800) & (data_no_outlier['price'] < 40000)]
# Out:
#                city                                              title  \
# 674   Jakarta Pusat  Rumah Kost 3 Lantai di Karang Anyar Sawah Besa...
# 1175          Bogor              Rumah Di Kota Wisata Cluster Virginia
# 1202          Depok  Rumah Megapolitan Cinere Depok Luas 1125 Dekat...
# 1450      Tangerang      Dijual Sangat Murah Rumah Alam Sutera Palmyra
#
#         price                    location    area  building_area  bedrooms  \
# 674    5000.0  Sawah Besar, Jakarta Pusat   160.0         3350.0      20.0
# 1175   5500.0          Kota Wisata, Bogor   425.0         2783.0       4.0
# 1202  20000.0               Cinere, Depok  1125.0         2500.0       8.0
# 1450   4000.0      Alam Sutera, Tangerang   200.0         1831.0       4.0
#
#       bathrooms  garage
# 674        10.0     1.0
# 1175        1.0     2.0
# 1202        5.0     5.0
# 1450        3.0     2.0

# %% [markdown]
# Hapus 4 data tersebut

# %%
len(data_no_outlier)
# Out:
# 1840

# %%
data_no_outlier = data_no_outlier[(data_no_outlier['building_area'] <= 1800) | (data_no_outlier['price'] >= 40000)]

# %%
len(data_no_outlier)
# Out:
# 1836

# %% [markdown]
# ## 9. Menampilkan Heatmap Correlation

# %% [markdown]
# Heatmap adalah visualisasi data dalam bentuk grid yang menampilkan nilai-nilai dalam bentuk warna. Pada correlation, nilai-nilai ini merepresentasi hubungan antara variabel. Semakin dekat warnanya dengan warna merah, semakin besar hubungan antara variabel tersebut (nilai korelasi mendekati 1, korelasi positif). Begitu juga, semakin dekat warnanya dengan warna biru, maka korelasi negatif. Jika nilai korelasi mendekati mendekati 0, maka kedua variabel tidak memiliki hubungan yang signifikan.

# %%
from sklearn.preprocessing import LabelEncoder

df_encoded = data_no_outlier.copy()
for column in df_encoded.select_dtypes(include=['object']).columns:
    df_encoded[column] = LabelEncoder().fit_transform(df_encoded[column])

corrmat = df_encoded.corr()

# membuat heatmap
f, ax = plt.subplots(figsize=(25, 25))
sns.heatmap(corrmat, vmin=-1, vmax=1, annot=True, square=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## 10. Simpan Data ke CSV

# %% [markdown]
# Setelah data bersih, maka perlu kita simpan ke dalam file CSV.

# %%
data_no_outlier.to_csv('harga_rumah_clean.csv')
print("data berhasil di ekspor")
# Out:
# data berhasil di ekspor
